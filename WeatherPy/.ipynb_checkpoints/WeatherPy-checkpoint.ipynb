# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=10)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=10)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "metric" 
# Build query URL
query_url = f"{url}appid={api_key}&units={units}&q="
requests.get(query_url + city).json()
# Out:
# {'coord': {'lon': 149.2, 'lat': -21.15},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 27.6,
#   'feels_like': 30.87,
#   'temp_min': 25.58,
#   'temp_max': 27.6,
#   'pressure': 1013,
#   'humidity': 78,
#   'sea_level': 1013,
#   'grnd_level': 1013},
#  'visibility': 10000,
#  'wind': {'speed': 4.42, 'deg': 328, 'gust': 6.1},
#  'clouds': {'all': 36},
#  'dt': 1634681085,
#  'sys': {'type': 2,
#   'id': 254970,
#   'country': 'AU',
#   'sunrise': 1634671691,
#   'sunset': 1634717254},
#  'timezone': 36000,
#  'id': 2159220,
#  'name': 'Mackay',
#  'cod': 200}

# %%
city_name = []
country_name = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
processing_record = 1
set_count = 1
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        processing_record = 0
    #endpoint url
    city_url = url + "&q=" + city
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        city_record = response["name"]
        country_name.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
    
        
        print(f"Processing Record {processing_record} of Set {set_count} | {city_record}")

        processing_record += 1
    except:
        print("City not found. Skipping...") 
    continue
# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | Tuktoyaktuk
# Processing Record 2 of Set 1 | Avarua
# Processing Record 3 of Set 1 | Ushuaia
# Processing Record 4 of Set 1 | Mahajanga
# Processing Record 5 of Set 1 | Hofn
# City not found. Skipping...
# Processing Record 6 of Set 1 | Cape Town
# Processing Record 7 of Set 1 | Pangnirtung
# Processing Record 8 of Set 1 | Kununurra
# Processing Record 9 of Set 1 | Khvastovichi
# Processing Record 10 of Set 1 | Kathu
# Processing Record 11 of Set 1 | Markova
# Processing Record 12 of Set 1 | Khatanga
# Processing Record 13 of Set 1 | Balagansk
# Processing Record 14 of Set 1 | Hong Kong
# Processing Record 15 of Set 1 | Fortuna
# Processing Record 16 of Set 1 | Rikitea
# Processing Record 17 of Set 1 | Abu Dhabi
# Processing Record 18 of Set 1 | Vardø
# City not found. Skipping...
# Processing Record 19 of Set 1 | Carbonia
# Processing Record 20 of Set 1 | Kaitangata
# Processing Record 21 of Set 1 | Wilmington
# Processing Record 22 of Set 1 | Butterworth
# Processing Record 23 of Set 1 | Dikson
# Processing Record 24 of Set 1 | Arraial do Cabo
# Processing Record 25 of Set 1 | Spring Valley
# Processing Record 26 of Set 1 | Bubaque
# Processing Record 27 of Set 1 | Butaritari
# Processing Record 28 of Set 1 | Valdivia
# Processing Record 29 of Set 1 | Bragança
# Processing Record 30 of Set 1 | Leningradskiy
# Processing Record 31 of Set 1 | Sarkand
# Processing Record 32 of Set 1 | Bahía de Caráquez
# Processing Record 33 of Set 1 | Jadu
# Processing Record 34 of Set 1 | Port Alfred
# Processing Record 35 of Set 1 | Yellowknife
# Processing Record 36 of Set 1 | Estremoz
# Processing Record 37 of Set 1 | Kapaa
# Processing Record 28 of Set 4 | Bambous Virieux
# Processing Record 29 of Set 4 | Quatre Cocos
# Processing Record 30 of Set 4 | Constitución
# Processing Record 31 of Set 4 | Noshiro
# Processing Record 32 of Set 4 | Rocha
# Processing Record 33 of Set 4 | Bredasdorp
# Processing Record 34 of Set 4 | Grand Gaube
# City not found. Skipping...
# Processing Record 35 of Set 4 | Paragominas
# Processing Record 36 of Set 4 | Akivīdu
# Processing Record 37 of Set 4 | Kamaishi
# Processing Record 38 of Set 4 | Qaanaaq
# Processing Record 39 of Set 4 | Nālūt
# Processing Record 40 of Set 4 | Safford
# Processing Record 41 of Set 4 | Altay
# Processing Record 42 of Set 4 | Ahlat
# Processing Record 43 of Set 4 | Portland
# Processing Record 44 of Set 4 | Whitefish
# Processing Record 45 of Set 4 | Yaan
# Processing Record 46 of Set 4 | Ko Samui
# Processing Record 47 of Set 4 | Bosobolo
# Processing Record 48 of Set 4 | Nanortalik
# Processing Record 0 of Set 5 | Lata
# Processing Record 1 of Set 5 | İmamoğlu
# Processing Record 2 of Set 5 | Atasū
# Processing Record 3 of Set 5 | Chāmpāhāti
# Processing Record 4 of Set 5 | Ratnagiri
# Processing Record 5 of Set 5 | Cidreira
# Processing Record 6 of Set 5 | Narsaq
# Processing Record 7 of Set 5 | Fairbanks
# City not found. Skipping...
# Processing Record 8 of Set 5 | Jiaocheng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 5 | Tilichiki
# Processing Record 10 of Set 5 | Vanavara
# Processing Record 11 of Set 5 | Mnogovershinnyy
# Processing Record 12 of Set 5 | Ahipara
# Processing Record 13 of Set 5 | Harnoli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 5 | Esperance
# Processing Record 15 of Set 5 | Sinnamary
# Processing Record 16 of Set 5 | Ubud
# Processing Record 17 of Set 5 | Evensk
# Processing Record 18 of Set 5 | Saint-Philippe
# Processing Record 19 of Set 5 | Clyde River
# Processing Record 20 of Set 5 | Guilin
# City not found. Skipping...
# Processing Record 21 of Set 5 | Viedma
# Processing Record 22 of Set 5 | Santa María del Oro
# Processing Record 23 of Set 5 | Opuwo
# Processing Record 24 of Set 5 | Hvolsvollur
# Processing Record 25 of Set 5 | Middletown
# Processing Record 26 of Set 5 | Konganāpuram
# Processing Record 27 of Set 5 | Linxia Chengguanzhen
# Processing Record 28 of Set 5 | São José da Coroa Grande
# City not found. Skipping...
# Processing Record 29 of Set 5 | Misratah
# Processing Record 30 of Set 5 | Toucheng
# Processing Record 31 of Set 5 | La Macarena
# Processing Record 32 of Set 5 | ‘Āhuimanu
# Processing Record 33 of Set 5 | Ribeira Grande
# Processing Record 34 of Set 5 | Mareeba
# Processing Record 35 of Set 5 | Teguise
# City not found. Skipping...
# Processing Record 36 of Set 5 | Kosh-Agach
# Processing Record 37 of Set 5 | Balkanabat
# Processing Record 38 of Set 5 | Laguna
# Processing Record 39 of Set 5 | Alyangula
# Processing Record 40 of Set 5 | New Norfolk
# Processing Record 41 of Set 5 | Trelew
# Processing Record 0 of Set 6 | Boyle
# City not found. Skipping...
# Processing Record 1 of Set 6 | Goderich
# Processing Record 2 of Set 6 | Bandarbeyla
# Processing Record 3 of Set 6 | Dubrovka
# City not found. Skipping...
# Processing Record 4 of Set 6 | Mahébourg
# Processing Record 5 of Set 6 | Saint George
# Processing Record 6 of Set 6 | Tautira
# Processing Record 7 of Set 6 | Roald
# Processing Record 8 of Set 6 | Şabyā
# Processing Record 9 of Set 6 | San José de Río Tinto
# Processing Record 10 of Set 6 | Posse
# Processing Record 11 of Set 6 | New Waterford
# Processing Record 12 of Set 6 | Tual
# Processing Record 13 of Set 6 | Puerto Baquerizo Moreno
# Processing Record 14 of Set 6 | Edd
# Processing Record 15 of Set 6 | Port Lincoln
# Processing Record 16 of Set 6 | Southbridge
# Processing Record 17 of Set 6 | Alta
# Processing Record 18 of Set 6 | Karaton
# Processing Record 19 of Set 6 | Ilhabela
# Processing Record 20 of Set 6 | Coyhaique
# Processing Record 21 of Set 6 | Victor Harbor
# Processing Record 22 of Set 6 | Kaélé
# Processing Record 23 of Set 6 | Airai
# Processing Record 24 of Set 6 | Bereda
# Processing Record 25 of Set 6 | Teya
# Processing Record 26 of Set 6 | Bindura
# Processing Record 27 of Set 6 | Tessalit
# Processing Record 28 of Set 6 | Yar-Sale
# Processing Record 29 of Set 6 | Geraldton
# Processing Record 30 of Set 6 | Port Moresby
# Processing Record 31 of Set 6 | Haines Junction
# Processing Record 32 of Set 6 | Nemuro
# Processing Record 33 of Set 6 | Valdez
# Processing Record 34 of Set 6 | Comodoro Rivadavia
# Processing Record 35 of Set 6 | Hendek
# Processing Record 36 of Set 6 | Lima
# Processing Record 37 of Set 6 | Kautokeino
# Processing Record 38 of Set 6 | Nha Trang
# Processing Record 39 of Set 6 | Kutum
# Processing Record 40 of Set 6 | Cururupu
# Processing Record 41 of Set 6 | Kota Kinabalu
# City not found. Skipping...
# Processing Record 42 of Set 6 | Korla
# Processing Record 43 of Set 6 | Samaná
# Processing Record 44 of Set 6 | Labuhan
# Processing Record 45 of Set 6 | São Benedito do Rio Preto
# Processing Record 46 of Set 6 | Tocopilla
# Processing Record 0 of Set 7 | Matara
# Processing Record 1 of Set 7 | North Bend
# Processing Record 2 of Set 7 | Nepānagar
# City not found. Skipping...
# Processing Record 3 of Set 7 | Saint-Pierre
# City not found. Skipping...
# Processing Record 4 of Set 7 | At-Bashi
# Processing Record 5 of Set 7 | Vendychany
# Processing Record 6 of Set 7 | Santa Rosa
# Processing Record 7 of Set 7 | Treinta y Tres
# Processing Record 8 of Set 7 | Nabire
# Processing Record 9 of Set 7 | Srednekolymsk
# Processing Record 10 of Set 7 | Camacha
# Processing Record 11 of Set 7 | Santa Fe
# City not found. Skipping...
# Processing Record 12 of Set 7 | San Quintín
# Processing Record 13 of Set 7 | Dingle
# Processing Record 14 of Set 7 | Jackson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 9 | Galesong
# Processing Record 0 of Set 10 | Tura
# Processing Record 1 of Set 10 | Ayagoz
# Processing Record 2 of Set 10 | Bilibino
# Processing Record 3 of Set 10 | Blacksburg
# Processing Record 4 of Set 10 | Guadalupe y Calvo
# Processing Record 5 of Set 10 | Powell
# Processing Record 6 of Set 10 | Horadiz
# Processing Record 7 of Set 10 | Terrace
# Processing Record 8 of Set 10 | Biscarrosse
# Processing Record 9 of Set 10 | Kloulklubed
# Processing Record 10 of Set 10 | Denizli Province
# Processing Record 11 of Set 10 | College
# Processing Record 12 of Set 10 | Rome
# Processing Record 13 of Set 10 | Palma di Montechiaro
# Processing Record 14 of Set 10 | Sri Aman
# Processing Record 15 of Set 10 | Antalaha
# Processing Record 16 of Set 10 | Aswān
# Processing Record 17 of Set 10 | Anito
# Processing Record 18 of Set 10 | Puerto Escondido
# Processing Record 19 of Set 10 | Buin
# Processing Record 20 of Set 10 | Mariehamn
# Processing Record 21 of Set 10 | Broken Hill
# Processing Record 22 of Set 10 | Empalme
# Processing Record 23 of Set 10 | Tago
# Processing Record 24 of Set 10 | Enid
# Processing Record 25 of Set 10 | Arnprior
# Processing Record 26 of Set 10 | Ürümqi
# Processing Record 27 of Set 10 | Sambava
# Processing Record 28 of Set 10 | Isangel
# City not found. Skipping...
# Processing Record 29 of Set 10 | Le Havre
# Processing Record 30 of Set 10 | Wajir
# Processing Record 31 of Set 10 | Pervomayskiy
# Processing Record 32 of Set 10 | Pingliang
# Processing Record 33 of Set 10 | Nelson Bay
# Processing Record 34 of Set 10 | Mechetinskaya
# Processing Record 35 of Set 10 | Barra de Tecoanapa
# Processing Record 36 of Set 10 | Qaqortoq
# Processing Record 37 of Set 10 | Lorengau
# City not found. Skipping...
# Processing Record 38 of Set 10 | Port Blair
# Processing Record 39 of Set 10 | Kisangani
# Processing Record 40 of Set 10 | Key West
# Processing Record 41 of Set 10 | Vallenar
# Processing Record 42 of Set 10 | Port Hardy
# Processing Record 43 of Set 10 | Dubuque
# Processing Record 44 of Set 10 | São João da Barra
# Processing Record 45 of Set 10 | Mossamedes
# Processing Record 46 of Set 10 | Tommot
# Processing Record 47 of Set 10 | Yala
# Processing Record 0 of Set 11 | Puri
# City not found. Skipping...
# Processing Record 1 of Set 11 | Redmond
# Processing Record 2 of Set 11 | Avera
# Processing Record 3 of Set 11 | Flin Flon
# Processing Record 4 of Set 11 | Dondo
# Processing Record 5 of Set 11 | Ubatuba
# Processing Record 6 of Set 11 | Inhambupe
# Processing Record 7 of Set 11 | Palmer
# Processing Record 8 of Set 11 | Slavutych
# Processing Record 9 of Set 11 | Hamilton
# Processing Record 10 of Set 11 | Shenjiamen
# Processing Record 11 of Set 11 | Campos Sales
# Processing Record 12 of Set 11 | Masuguru
# Processing Record 13 of Set 11 | Temecula
# Processing Record 14 of Set 11 | Maxixe
# Processing Record 15 of Set 11 | Chokurdakh
# Processing Record 16 of Set 11 | Fuyang
# Processing Record 17 of Set 11 | Vyshhorod
# Processing Record 18 of Set 11 | Elbistan
# Processing Record 19 of Set 11 | Kampot
# Processing Record 20 of Set 11 | Sola
# Processing Record 21 of Set 11 | Kebumen
# City not found. Skipping...
# Processing Record 22 of Set 11 | Buchloe
# Processing Record 23 of Set 11 | Galiākot
# Processing Record 24 of Set 11 | Maragogi
# Processing Record 25 of Set 11 | Adrar
# City not found. Skipping...
# Processing Record 26 of Set 11 | Novaya Igirma
# Processing Record 27 of Set 11 | Iracoubo
# Processing Record 28 of Set 11 | Nouadhibou
# Processing Record 29 of Set 11 | Walvis Bay
# Processing Record 30 of Set 11 | Luganville
# Processing Record 31 of Set 11 | Andenes
# Processing Record 32 of Set 11 | Faya
# Processing Record 33 of Set 11 | Baringo
# Processing Record 34 of Set 11 | Semme
# Processing Record 35 of Set 11 | Lompoc
# Processing Record 36 of Set 11 | Kuchinarai
# Processing Record 37 of Set 11 | Maţāy
# Processing Record 38 of Set 11 | Shimoda
# Processing Record 39 of Set 11 | Honiara
# Processing Record 40 of Set 11 | Parrita
# Processing Record 41 of Set 11 | Kuusamo
# Processing Record 42 of Set 11 | Dandong
# Processing Record 43 of Set 11 | Dunedin
# Processing Record 44 of Set 11 | Västerås
# Processing Record 45 of Set 11 | Ouésso
# Processing Record 46 of Set 11 | Salaga
# Processing Record 0 of Set 12 | Salalah
# Processing Record 1 of Set 12 | Banes
# Processing Record 2 of Set 12 | San Juan
# Processing Record 3 of Set 12 | São Filipe
# Processing Record 4 of Set 12 | Havøysund
# Processing Record 5 of Set 12 | Río Gallegos
# Processing Record 6 of Set 12 | La Ronge
# Processing Record 7 of Set 12 | Benghazi
# Processing Record 8 of Set 12 | Zhangjiakou Shi Xuanhua Qu
# City not found. Skipping...
# Processing Record 9 of Set 12 | Batticaloa
# Processing Record 10 of Set 12 | Podgornoye
# Processing Record 11 of Set 12 | Selikhino
# Processing Record 12 of Set 12 | Mahibadhoo
# Processing Record 13 of Set 12 | Dargaville
# Processing Record 14 of Set 12 | Laas
# Processing Record 15 of Set 12 | Fort Nelson
# Processing Record 16 of Set 12 | Cockburn Town
# Processing Record 17 of Set 12 | Alugan
# Processing Record 18 of Set 12 | Kalemie
# Processing Record 19 of Set 12 | Shubarkuduk
# Processing Record 20 of Set 12 | Dali
# Processing Record 21 of Set 12 | Angoche
# Processing Record 22 of Set 12 | Chilliwack
# Processing Record 23 of Set 12 | Denpasar
# Processing Record 24 of Set 12 | Moose Factory
# Processing Record 25 of Set 12 | Puksoozero
# Processing Record 26 of Set 12 | Surgut
# Processing Record 27 of Set 12 | Lábrea
# Processing Record 28 of Set 12 | Katherine
# Processing Record 29 of Set 12 | Reni
# Processing Record 30 of Set 12 | Whitecourt
# Processing Record 31 of Set 12 | Caucayá
# Processing Record 32 of Set 12 | Mandalgovi
# Processing Record 33 of Set 12 | Mala Bilozerka
# Processing Record 34 of Set 12 | Staritsa
# Processing Record 35 of Set 12 | Ca Mau
# Processing Record 36 of Set 12 | Tezu
# Processing Record 37 of Set 12 | Westport
# Processing Record 38 of Set 12 | Iqaluit
# Processing Record 39 of Set 12 | Okha
# City not found. Skipping...
# Processing Record 40 of Set 12 | Manjacaze
# Processing Record 41 of Set 12 | Nishihara
# Processing Record 42 of Set 12 | Charlottesville
# Processing Record 43 of Set 12 | Touros
# Processing Record 44 of Set 12 | Frontignan
# Processing Record 45 of Set 12 | Henties Bay
# Processing Record 46 of Set 12 | Mackay
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#df for city, lat, lng, max temp, humidity, cloudiness, wind speed, country, and date
#go back and add all of those to your loop and make empty lists for them 
#create dictionary 
df_1= pd.DataFrame({
    "City": city_name,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country_name,
    "Date": date,
})
#drop skipped rows 
df_1 = df_1.dropna(how="any")

df_1
#hopefully will work when API key works again
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0        Tuktoyaktuk   69.4541  -133.0374            -4.46        72
# 1             Avarua  -21.2078  -159.7750            25.03        57
# 2            Ushuaia  -54.8000   -68.3000            14.81        47
# 3          Mahajanga  -15.7167    46.3167            24.01        83
# 4               Hofn   64.2539   -15.2082             1.79        65
# ..               ...       ...        ...              ...       ...
# 553  Charlottesville   38.0293   -78.4767            21.62        56
# 554           Touros   -5.1989   -35.4608            26.50        80
# 555       Frontignan   43.4485     3.7540            19.08        93
# 556      Henties Bay  -22.1160    14.2845            15.48        90
# 557           Mackay  -21.1500   149.2000            28.16        78
#
#      Cloudiness  Wind Speed Country        Date
# 0            13        5.73      CA  1634681387
# 1            94        3.60      CK  1634681388
# 2            75        5.14      AR  1634681388
# 3            20        1.54      MG  1634681798
# 4             4        9.12      IS  1634681798
# ..          ...         ...     ...         ...
# 553           1        2.68      US  1634681270
# 554          37        7.10      BR  1634681566
# 555         100        6.93      FR  1634681566
# 556          87        3.30      NA  1634681490
# 557          36        4.42      AU  1634681857
#
# [558 rows x 9 columns]

# %%
df_1.head()
# Out:
#           City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0  Tuktoyaktuk   69.4541  -133.0374            -4.46        72          13
# 1       Avarua  -21.2078  -159.7750            25.03        57          94
# 2      Ushuaia  -54.8000   -68.3000            14.81        47          75
# 3    Mahajanga  -15.7167    46.3167            24.01        83          20
# 4         Hofn   64.2539   -15.2082             1.79        65           4
#
#    Wind Speed Country        Date
# 0        5.73      CA  1634681387
# 1        3.60      CK  1634681388
# 2        5.14      AR  1634681388
# 3        1.54      MG  1634681798
# 4        9.12      IS  1634681798

# %%
#create statistic summary table for data 
lat_stat= df_1["Latitude"].describe()
long_stat= df_1["Longitude"].describe()
max_stat=df_1["Max Temperature"].describe()
humid_stat= df_1["Humidity"].describe()
cloud_stat= df_1["Cloudiness"].describe()
wind_stat= df_1["Wind Speed"].describe()
date_stat= df_1["Date"].describe()

# %%
df_2= pd.DataFrame({
    "Lat":lat_stat,
    "Lng": long_stat,
    "Max Temp": max_stat,
    "Humidity": humid_stat,
    "Cloudiness": cloud_stat,
    "Wind Speed": wind_stat,
    "Date": date_stat
})
df_2
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  558.000000  558.000000  558.000000  558.000000  558.000000  558.000000
# mean    20.919151   19.129882   15.712115   71.227599   57.146953    3.495609
# std     32.902317   90.455178   11.358670   20.081347   39.568497    2.520596
# min    -54.800000 -175.200000  -26.910000   10.000000    0.000000    0.000000
# 25%     -5.592175  -65.610650    7.742500   58.000000   14.000000    1.605000
# 50%     25.167900   27.498300   18.590000   75.500000   71.500000    2.945000
# 75%     48.026375  100.361425   24.820000   86.000000   98.000000    4.667500
# max     78.218600  179.316700   34.050000  100.000000  100.000000   14.830000
#
#                Date
# count  5.580000e+02
# mean   1.634681e+09
# std    9.194231e+01
# min    1.634681e+09
# 25%    1.634681e+09
# 50%    1.634681e+09
# 75%    1.634682e+09
# max    1.634682e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df_2
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  558.000000  558.000000  558.000000  558.000000  558.000000  558.000000
# mean    20.919151   19.129882   15.712115   71.227599   57.146953    3.495609
# std     32.902317   90.455178   11.358670   20.081347   39.568497    2.520596
# min    -54.800000 -175.200000  -26.910000   10.000000    0.000000    0.000000
# 25%     -5.592175  -65.610650    7.742500   58.000000   14.000000    1.605000
# 50%     25.167900   27.498300   18.590000   75.500000   71.500000    2.945000
# 75%     48.026375  100.361425   24.820000   86.000000   98.000000    4.667500
# max     78.218600  179.316700   34.050000  100.000000  100.000000   14.830000
#
#                Date
# count  5.580000e+02
# mean   1.634681e+09
# std    9.194231e+01
# min    1.634681e+09
# 25%    1.634681e+09
# 50%    1.634681e+09
# 75%    1.634682e+09
# max    1.634682e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity = df_1[(df_1["Humidity"] > 100)].index
print("There are no cities in this dataframe that have a humidity level of over 100%")
# Out:
# There are no cities in this dataframe that have a humidity level of over 100%

# %%
len(df_1)
# Out:
# 558

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#x and y values 
x_values1 = df_1["Latitude"]
y_values1 = df_1["Max Temperature"]
#plotting
fig1, ax1 = plt.subplots(figsize=(10,10))

#adding titles etc
plt.title(f"City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.scatter(x_values1, y_values1, edgecolor="purple", linewidth=1, marker="*", alpha=1)

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#repeat but change values
x_values2 = df_1["Latitude"]
y_values2 = df_1["Humidity"]
#plot
fig1, ax1 = plt.subplots(figsize=(10, 10))
plt.scatter(x_values2, y_values2, edgecolor="purple", linewidth=1, marker="*", alpha=1)

#add title etc
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity")
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#repeat change variables 
x_values3 = df_1["Latitude"]
y_values3 = df_1["Cloudiness"]
#plot 
fig1, ax1 = plt.subplots(figsize=(10,10))
plt.scatter(x_values3, y_values3, edgecolor="purple", linewidth=1, marker="*", alpha=1)


#add title etc
plt.title(f"City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()


plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values4 = df_1["Latitude"]
y_values4 = df_1["Wind Speed"]
#Plot
fig1, ax1 = plt.subplots(figsize=(10,10))
plt.scatter(x_values4, y_values4, edgecolor="purple", linewidth=1, marker="*", alpha=1)
#Add title etc
plt.title(f"City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
