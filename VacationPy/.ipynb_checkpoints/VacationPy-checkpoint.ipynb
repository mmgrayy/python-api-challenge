# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json 

# input csv data file
input_data_file = "../WeatherPy/output_data/cities.csv"
output_data_file = "../output_data/map.csv"

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df_1=pd.read_csv(input_data_file)
df_1
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0              Edson   53.5835  -116.4356            59.14        36
# 1          Guangzhou   23.1167   113.2500            60.94        71
# 2         Nikolskoye   59.7035    30.7861            53.87        85
# 3    Havre-St-Pierre   50.2334   -63.5986            50.00        87
# 4           Kuril'sk   45.2333   147.8833            41.11        84
# ..               ...       ...        ...              ...       ...
# 570       ‘Ewa Beach   21.3156  -158.0072            84.15        62
# 571        Ulladulla  -35.3500   150.4667            66.09        84
# 572            Semey   50.4111    80.2275            43.86        83
# 573        Kilindoni   -7.9139    39.6668            77.50        77
# 574         Bay City   43.5945   -83.8889            54.64        93
#
#      Cloudiness  Wind Speed Country        Date
# 0             1        8.05      CA  1634854598
# 1            95       12.75      CN  1634854289
# 2           100       16.40      RU  1634854598
# 3             1        4.61      CA  1634854598
# 4           100        4.29      RU  1634854599
# ..          ...         ...     ...         ...
# 570          75       10.00      US  1634854787
# 571          32        2.15      AU  1634854788
# 572         100       16.55      KZ  1634854789
# 573          19       12.08      TZ  1634854789
# 574          90       18.41      US  1634854707
#
# [575 rows x 9 columns]

# %%
df_1.dtypes
# Out:
# City                object
# Latitude           float64
# Longitude          float64
# Max Temperature    float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# Country             object
# Date                 int64
# dtype: object

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#gmaps
gmaps.configure(api_key=g_key)

# %%
# Use the Lat and Lng as locations and Humidity as the weight.
locations = df_1[['Latitude', 'Longitude']]
weights = df_1['Humidity']

# %%
humidity_fig = gmaps.figure(map_type="HYBRID")
heatmap_layer=gmaps.heatmap_layer(locations,weights=weights)

# Addimg Heatmap layer to map
humidity_fig.add_layer(heatmap_layer)
heatmap_layer.max_intensity = df_1['Humidity'].max()
heatmap_layer.point_radius = 10
humidity_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
df_1
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0              Edson   53.5835  -116.4356            59.14        36
# 1          Guangzhou   23.1167   113.2500            60.94        71
# 2         Nikolskoye   59.7035    30.7861            53.87        85
# 3    Havre-St-Pierre   50.2334   -63.5986            50.00        87
# 4           Kuril'sk   45.2333   147.8833            41.11        84
# ..               ...       ...        ...              ...       ...
# 570       ‘Ewa Beach   21.3156  -158.0072            84.15        62
# 571        Ulladulla  -35.3500   150.4667            66.09        84
# 572            Semey   50.4111    80.2275            43.86        83
# 573        Kilindoni   -7.9139    39.6668            77.50        77
# 574         Bay City   43.5945   -83.8889            54.64        93
#
#      Cloudiness  Wind Speed Country        Date
# 0             1        8.05      CA  1634854598
# 1            95       12.75      CN  1634854289
# 2           100       16.40      RU  1634854598
# 3             1        4.61      CA  1634854598
# 4           100        4.29      RU  1634854599
# ..          ...         ...     ...         ...
# 570          75       10.00      US  1634854787
# 571          32        2.15      AU  1634854788
# 572         100       16.55      KZ  1634854789
# 573          19       12.08      TZ  1634854789
# 574          90       18.41      US  1634854707
#
# [575 rows x 9 columns]

# %%
#My weather conditions 
ideal_weather= df_1

# A max temperature lower than 80 degrees but higher than 70.
ideal_weather = ideal_weather.loc[(ideal_weather["Max Temperature"] < 80) & (ideal_weather["Max Temperature"] > 70)]

# Wind speed less than 10 mph.
ideal_weather = ideal_weather.loc[ideal_weather["Wind Speed"] < 10]

# Zero cloudiness.
ideal_weather = ideal_weather.loc[ideal_weather["Cloudiness"] == 0]

# Drop any rows with null values
ideal_weather = ideal_weather.dropna()

ideal_weather
# Out:
#               City  Latitude  Longitude  Max Temperature  Humidity  \
# 72   Venado Tuerto  -33.7456   -61.9688            77.79        32
# 85   Mar del Plata  -38.0023   -57.5575            75.22        90
# 110          Junín  -34.5838   -60.9433            78.98        34
# 161     Saint-Paul  -21.0096    55.2707            71.71        84
# 287   Saint-Pierre  -21.3393    55.4781            71.28        69
# 449  Alice Springs  -23.7000   133.8833            72.95        27
# 523   Campo Grande  -20.4428   -54.6464            78.35        44
# 538     Gangānagar   29.9167    73.8833            75.27        30
#
#      Cloudiness  Wind Speed Country        Date
# 72            0        8.37      AR  1634854620
# 85            0        3.00      AR  1634854625
# 110           0        5.91      AR  1634854450
# 161           0        1.99      RE  1634854651
# 287           0        6.91      RE  1634854694
# 449           0        6.91      AU  1634854745
# 523           0        5.75      BR  1634854773
# 538           0        8.12      IN  1634854778

# %%
len(ideal_weather)
# Out:
# 8

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = df_1

# params dictionary to update each iteration
params = {
    "radius": 5000,"types": "lodging","key": g_key}


for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Latitude"]
    lng = row["Longitude"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row['City']}.")
    response = requests.get(base_url, params=params).json()
    # print(json.dumps(response, indent=4, sort_keys=True))
    
    # extract results
    results = response['results']
    
    try:
        print(f"Nearest Hotel {results[0]['name']}.")
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing Results.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: Edson.
# Nearest Hotel Holiday Inn Express & Suites Edson, an IHG Hotel.
# ------------
# Retrieving Results for Index 1: Guangzhou.
# Nearest Hotel Guangzhou Hotel.
# ------------
# Retrieving Results for Index 2: Nikolskoye.
# Nearest Hotel Tourist House - Sablino.
# ------------
# Retrieving Results for Index 3: Havre-St-Pierre.
# Nearest Hotel Auberge Niapiskau.
# ------------
# Retrieving Results for Index 4: Kuril'sk.
# Nearest Hotel Hotel Ostrov.
# ------------
# Retrieving Results for Index 5: Atuona.
# Nearest Hotel Villa Enata.
# ------------
# Retrieving Results for Index 6: Hermanus.
# Nearest Hotel Misty Waves Boutique Hotel.
# ------------
# Retrieving Results for Index 7: Punta Arenas.
# Nearest Hotel Hotel Dreams Del Estrecho.
# ------------
# Retrieving Results for Index 8: Souillac.
# Nearest Hotel Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 9: Taoudenni.
# Missing Results.
# ------------
# Retrieving Results for Index 10: Hasaki.
# Nearest Hotel Hotel Sunrise Choshi.
# ------------
# Retrieving Results for Index 11: Chokurdakh.
# Missing Results.
# ------------
# Retrieving Results for Index 12: Aklavik.
# Nearest Hotel Aklavik Inn.
# ------------
# Retrieving Results for Index 13: Ponta do Sol.
# Nearest Hotel Hotel do Campo.
# ------------
# Retrieving Results for Index 14: Beira.
# Nearest Hotel Beira Terrace Hotel.
# ------------
# Retrieving Results for Index 15: New Norfolk.
# Nearest Hotel The Shingles Riverside Cottages.
# ------------
# Retrieving Results for Index 16: Port Alfred.
# Nearest Hotel The Halyards Hotel.
# ------------
# Retrieving Results for Index 17: Jamestown.
# Nearest Hotel Hampton Inn & Suites Jamestown.
# ------------
# Retrieving Results for Index 18: Tiksi.
# Nearest Hotel Arktika.
# ------------
# Retrieving Results for Index 19: Tuatapere.
# Nearest Hotel Ron and Tony's Bed & Breakfast.
# ------------
# Retrieving Results for Index 20: Lebu.
# Nearest Hotel Hostal Las Lilas.
# ------------
# Retrieving Results for Index 21: Chui.
# Nearest Hotel Nuevo Hotel Plaza.
# ------------
# Retrieving Results for Index 22: Gelemso.
# Nearest Hotel Kerod Hotel.
# ------------
# Retrieving Results for Index 23: Albany.
# Missing Results.
# ------------
# Retrieving Results for Index 24: Orchard Homes.
# Nearest Hotel Broadway Inn Missoula.
# ------------
# Retrieving Results for Index 25: Srednekolymsk.
# Missing Results.
# ------------
# Retrieving Results for Index 26: Coimbra.
# Nearest Hotel Hotel Quinta das Lágrimas.
# ------------
# Retrieving Results for Index 27: Salalah.
# Nearest Hotel HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel.
# ------------
# Retrieving Results for Index 28: Upernavik.
# Nearest Hotel Gina's Guesthouse - Upernavik.
# ------------
# Retrieving Results for Index 29: Barrow.
# Nearest Hotel King Eider Inn.
# ------------
# Retrieving Results for Index 30: Mataura.
# Nearest Hotel Ellie's Villa.
# ------------
# Retrieving Results for Index 31: Khatanga.
# Nearest Hotel Gostinitsa "Zapolyar'ye".
# ------------
# Retrieving Results for Index 32: Jega.
# Nearest Hotel ALH. Nasiru Ibrahim.
# ------------
# Retrieving Results for Index 33: Arraial do Cabo.
# Nearest Hotel Pousada Porto Praia.
# ------------
# Retrieving Results for Index 34: Mezen'.
# Nearest Hotel Gostevoy Dom Everest.
# ------------
# Retrieving Results for Index 35: Torbay.
# Nearest Hotel Gallows Cove.
# ------------
# Retrieving Results for Index 36: Ahipara.
# Nearest Hotel Ahipara Holiday Park.
# ------------
# Retrieving Results for Index 37: Koson.
# Missing Results.
# ------------
# Retrieving Results for Index 38: Ushuaia.
# Nearest Hotel Albatros Hotel.
# ------------
# Retrieving Results for Index 39: Cumberland.
# Nearest Hotel American Eagle Inn.
# ------------
# Retrieving Results for Index 40: Busselton.
# Nearest Hotel Observatory Guest House.
# ------------
# Retrieving Results for Index 41: Sidi Ali.
# Missing Results.
# ------------
# Retrieving Results for Index 42: Waipawa.
# Nearest Hotel Tora Coastal Walk.
# ------------
# Retrieving Results for Index 43: Rikitea.
# Nearest Hotel People ThankYou.
# ------------
# Retrieving Results for Index 44: Tahe.
# Nearest Hotel 塔河宾馆.
# ------------
# Retrieving Results for Index 45: Hithadhoo.
# Nearest Hotel Scoop Guest House.
# ------------
# Retrieving Results for Index 46: Iqaluit.
# Nearest Hotel Frobisher Inn.
# ------------
# Retrieving Results for Index 47: Almaznyy.
# Missing Results.
# ------------
# Retrieving Results for Index 48: Kapaa.
# Nearest Hotel Sheraton Kauai Coconut Beach Resort.
# ------------
# Retrieving Results for Index 49: Kavieng.
# Nearest Hotel Nusa Island Retreat.
# ------------
# Retrieving Results for Index 50: Avarua.
# Nearest Hotel Paradise Inn.
# ------------
# Retrieving Results for Index 51: Carnarvon.
# Nearest Hotel Hospitality Carnarvon.
# ------------
# Retrieving Results for Index 52: Verāval.
# Nearest Hotel Lords Inn Somnath.
# ------------
# Retrieving Results for Index 53: Bredasdorp.
# Nearest Hotel Bredasdorp Country Manor.
# ------------
# Retrieving Results for Index 54: Digby.
# Nearest Hotel Digby Pines Golf Resort and Spa.
# ------------
# Retrieving Results for Index 55: Bluff.
# Nearest Hotel Bluff Homestead - Guesthouse & Campervan Park.
# ------------
# Retrieving Results for Index 56: Buraidah.
# Nearest Hotel فندق راحة السلام.
# ------------
# Retrieving Results for Index 57: Moerai.
# Nearest Hotel Le Manotel.
# ------------
# Retrieving Results for Index 58: Ranau.
# Nearest Hotel The Second Room.
# ------------
# Retrieving Results for Index 59: Pochutla.
# Nearest Hotel Hotel Posada San Jose.
# ------------
# Retrieving Results for Index 60: Longyearbyen.
# Nearest Hotel Radisson Blu Polar Hotel, Spitsbergen.
# ------------
# Retrieving Results for Index 61: Codrington.
# Nearest Hotel Codrington Gardens Bed And Breakfast.
# ------------
# Retrieving Results for Index 62: Tarifa.
# Nearest Hotel HOSPEDAJE FACUNDO.
# ------------
# Retrieving Results for Index 63: Saint-François.
# Nearest Hotel Manoir Du Bonheur.
# ------------
# Retrieving Results for Index 64: Severo-Kuril'sk.
# Nearest Hotel Kak Doma.
# ------------
# Retrieving Results for Index 65: Spornoye.
# Missing Results.
# ------------
# Retrieving Results for Index 66: Cidreira.
# Nearest Hotel Hotel Castelo.
# ------------
# Retrieving Results for Index 67: Olafsvik.
# Nearest Hotel Hotel Olafsvik.
# ------------
# Retrieving Results for Index 68: Port Hardy.
# Nearest Hotel Airport Inn.
# ------------
# Retrieving Results for Index 69: Iringa.
# Nearest Hotel M.R. Hotels ltd..
# ------------
# Retrieving Results for Index 70: Coyhaique.
# Nearest Hotel Diego De Almagro Coyhaique.
# ------------
# Retrieving Results for Index 71: Port Hawkesbury.
# Nearest Hotel MacKenzie House Tourist Home B&B.
# ------------
# Retrieving Results for Index 72: Venado Tuerto.
# Nearest Hotel Hotel - Miro Park.
# ------------
# Retrieving Results for Index 73: Smolenka.
# Nearest Hotel Russkaya Usadba v Zarechye.
# ------------
# Retrieving Results for Index 74: Tasiilaq.
# Nearest Hotel The Red House.
# ------------
# Retrieving Results for Index 75: Toledo.
# Nearest Hotel Hotel Carlos V Toledo.
# ------------
# Retrieving Results for Index 76: Ostrovnoy.
# Missing Results.
# ------------
# Retrieving Results for Index 77: Mossamedes.
# Nearest Hotel Hotel Chik Chik Namibe.
# ------------
# Retrieving Results for Index 78: Klaksvík.
# Nearest Hotel Airbnb rooms.
# ------------
# Retrieving Results for Index 79: Kedrovka.
# Nearest Hotel Гостиница «Олимпия».
# ------------
# Retrieving Results for Index 80: Pontian Kecil.
# Nearest Hotel SUNFLOWER EXPRESS HOTEL.
# ------------
# Retrieving Results for Index 81: São Filipe.
# Nearest Hotel Hotel Xaguate.
# ------------
# Retrieving Results for Index 82: Saint Anthony.
# Nearest Hotel Holiday Inn Express Roseville-St. Paul, an IHG Hotel.
# ------------
# Retrieving Results for Index 83: Hilo.
# Nearest Hotel Hilo Hawaiian Hotel.
# ------------
# Retrieving Results for Index 84: Kasama.
# Nearest Hotel Kalebalika Cottages.
# ------------
# Retrieving Results for Index 85: Mar del Plata.
# Nearest Hotel Gran Hotel Mar del Plata.
# ------------
# Retrieving Results for Index 86: Östersund.
# Nearest Hotel Best Western Hotel Gamla Teatern.
# ------------
# Retrieving Results for Index 87: Bethel.
# Nearest Hotel Courtyard by Marriott Danbury.
# ------------
# Retrieving Results for Index 88: Asău.
# Nearest Hotel Casa Mika Ciobanus.
# ------------
# Retrieving Results for Index 89: Qasigiannguit.
# Nearest Hotel Hotel Diskobay.
# ------------
# Retrieving Results for Index 90: Norman Wells.
# Nearest Hotel Heritage Hotel.
# ------------
# Retrieving Results for Index 91: Tazovsky.
# Nearest Hotel TazHostel.
# ------------
# Retrieving Results for Index 92: Nemuro.
# Nearest Hotel Hotel Nemuro Kaiyoutei.
# ------------
# Retrieving Results for Index 93: Nanortalik.
# Nearest Hotel Hotel Kap Farvel.
# ------------
# Retrieving Results for Index 94: Ilulissat.
# Nearest Hotel Hotel Arctic.
# ------------
# Retrieving Results for Index 95: Provideniya.
# Missing Results.
# ------------
# Retrieving Results for Index 96: Udachny.
# Nearest Hotel Severnoye Siyaniye.
# ------------
# Retrieving Results for Index 97: Deputatsky.
# Nearest Hotel Baza Otdykha.
# ------------
# Retrieving Results for Index 98: Belaya Gora.
# Missing Results.
# ------------
# Retrieving Results for Index 99: Airai.
# Nearest Hotel Juvinal Martin.
# ------------
# Retrieving Results for Index 100: Tupik.
# Nearest Hotel Guest House Orkhideya.
# ------------
# Retrieving Results for Index 101: Garoowe.
# Nearest Hotel Curubo Hotel.
# ------------
# Retrieving Results for Index 102: Monrovia.
# Nearest Hotel Sunset Inn.
# ------------
# Retrieving Results for Index 103: Katsuura.
# Nearest Hotel Katsuura Hotel Mikazuki.
# ------------
# Retrieving Results for Index 104: Cape Town.
# Nearest Hotel Southern Sun Waterfront Cape Town.
# ------------
# Retrieving Results for Index 105: Tres Arroyos.
# Nearest Hotel Habitacion Triple con baño y entrada privada.
# ------------
# Retrieving Results for Index 106: Qaanaaq.
# Nearest Hotel Qaanaaq Hotel.
# ------------
# Retrieving Results for Index 107: Safi.
# Nearest Hotel Hôtel Abda.
# ------------
# Retrieving Results for Index 108: Quatre Cocos.
# Nearest Hotel Sunrise Attitude Hotel.
# ------------
# Retrieving Results for Index 109: Hwange.
# Nearest Hotel Hwange Colliery Guest House.
# ------------
# Retrieving Results for Index 110: Junín.
# Nearest Hotel Hotel Central.
# ------------
# Retrieving Results for Index 111: Requena.
# Nearest Hotel Hotel Avenida.
# ------------
# Retrieving Results for Index 112: Bengkulu.
# Nearest Hotel Grage Hotel Bengkulu.
# ------------
# Retrieving Results for Index 113: Kysyl-Syr.
# Missing Results.
# ------------
# Retrieving Results for Index 114: Moundou.
# Nearest Hotel Planete Life.
# ------------
# Retrieving Results for Index 115: Khovd.
# Nearest Hotel Hotel Khovd.
# ------------
# Retrieving Results for Index 116: Tekeli.
# Nearest Hotel Vuslat Tekeli.
# ------------
# Retrieving Results for Index 117: Ancud.
# Nearest Hotel Hotel Arena Gruesa.
# ------------
# Retrieving Results for Index 118: Champerico.
# Nearest Hotel Hotel y restaurante "El Diamante".
# ------------
# Retrieving Results for Index 119: Pudozh.
# Nearest Hotel Guest-House na Transportnoy.
# ------------
# Retrieving Results for Index 120: Manakara.
# Nearest Hotel La Residence Manakara.
# ------------
# Retrieving Results for Index 121: Weligama.
# Nearest Hotel Weligama Bay Resort.
# ------------
# Retrieving Results for Index 122: Barddhamān.
# Nearest Hotel Sinclairs Tourist Resort, Burdwan.
# ------------
# Retrieving Results for Index 123: Nouadhibou.
# Nearest Hotel El Medina.
# ------------
# Retrieving Results for Index 124: Nkhotakota.
# Nearest Hotel Sitima Inn.
# ------------
# Retrieving Results for Index 125: Ponta Delgada.
# Nearest Hotel Vila Nova Hotel.
# ------------
# Retrieving Results for Index 126: Puerto Ayora.
# Nearest Hotel Finch Bay Galapagos Hotel.
# ------------
# Retrieving Results for Index 127: Hervey Bay.
# Nearest Hotel Shelly Bay Resort.
# ------------
# Retrieving Results for Index 128: Yerbogachën.
# Missing Results.
# ------------
# Retrieving Results for Index 129: Kalach-na-Donu.
# Nearest Hotel Hotel Laguna.
# ------------
# Retrieving Results for Index 130: Homer.
# Nearest Hotel Beluga Lake Lodge.
# ------------
# Retrieving Results for Index 131: Ketchikan.
# Nearest Hotel Snow's Cove Lodge.
# ------------
# Retrieving Results for Index 132: Saldanha.
# Nearest Hotel Blue Bay Lodge.
# ------------
# Retrieving Results for Index 133: Córdoba.
# Nearest Hotel Hotel Sussex.
# ------------
# Retrieving Results for Index 134: Tarragona.
# Nearest Hotel Hotel SB Ciutat de Tarragona.
# ------------
# Retrieving Results for Index 135: Kiryat Gat.
# Nearest Hotel OlusHome.
# ------------
# Retrieving Results for Index 136: Mayo.
# Nearest Hotel Resorts Resource Group International.
# ------------
# Retrieving Results for Index 137: Mandalgovi.
# Nearest Hotel В.Ганбат.
# ------------
# Retrieving Results for Index 138: Saint-Philippe.
# Nearest Hotel Chambres d'hôte "La Trinité".
# ------------
# Retrieving Results for Index 139: Lufilufi.
# Nearest Hotel Leuaina Beach Resort and Spa.
# ------------
# Retrieving Results for Index 140: Constitución.
# Nearest Hotel Hotel Boutique Las Azucenas.
# ------------
# Retrieving Results for Index 141: Doha.
# Nearest Hotel Movenpick Hotel Doha.
# ------------
# Retrieving Results for Index 142: Grand Gaube.
# Nearest Hotel Veranda Paul et Virginie Hotel & Spa.
# ------------
# Retrieving Results for Index 143: Turtas.
# Nearest Hotel Domashnyaya Gostinitsa.
# ------------
# Retrieving Results for Index 144: Colorines.
# Nearest Hotel La Capilla Hotel Boutique.
# ------------
# Retrieving Results for Index 145: Husavik.
# Nearest Hotel Bjarnabúð.
# ------------
# Retrieving Results for Index 146: Māndvi.
# Nearest Hotel Jitendra Guest House.
# ------------
# Retrieving Results for Index 147: Khani.
# Nearest Hotel კურორტი ზეკარი/Resort Zekari.
# ------------
# Retrieving Results for Index 148: Anadyr.
# Nearest Hotel Отке17 — посуточная аренда жилья для командированных.
# ------------
# Retrieving Results for Index 149: Talnakh.
# Nearest Hotel Talnakh Hotel.
# ------------
# Retrieving Results for Index 150: Ferkessédougou.
# Nearest Hotel Hotel Chateau.
# ------------
# Retrieving Results for Index 151: Wanning.
# Nearest Hotel Paradise Hotel.
# ------------
# Retrieving Results for Index 152: Tamiahua.
# Nearest Hotel Mission Of The Sun Hotel.
# ------------
# Retrieving Results for Index 153: Katangli.
# Missing Results.
# ------------
# Retrieving Results for Index 154: Bobo-Dioulasso.
# Nearest Hotel RAN Hotel Somketa.
# ------------
# Retrieving Results for Index 155: Chapais.
# Nearest Hotel Hôtel Opémiska.
# ------------
# Retrieving Results for Index 156: Cherskiy.
# Nearest Hotel Gostinitsa.
# ------------
# Retrieving Results for Index 157: Puerto Carreño.
# Nearest Hotel Casa Hotel Victoria.
# ------------
# Retrieving Results for Index 158: Kamenka.
# Missing Results.
# ------------
# Retrieving Results for Index 159: Castro.
# Nearest Hotel CHACARA BAILLY.
# ------------
# Retrieving Results for Index 160: Port Lincoln.
# Nearest Hotel Port Lincoln Hotel.
# ------------
# Retrieving Results for Index 161: Saint-Paul.
# Nearest Hotel Boucan Canot.
# ------------
# Retrieving Results for Index 162: Saint Paul Harbor.
# Nearest Hotel Best Western Kodiak Inn And Convention Center.
# ------------
# Retrieving Results for Index 163: Huicheng.
# Nearest Hotel Huilai Hotel.
# ------------
# Retrieving Results for Index 164: Natal.
# Nearest Hotel Villa Park Hotel | Natal.
# ------------
# Retrieving Results for Index 165: Taylor.
# Nearest Hotel Elm Creek Bed & Breakfast.
# ------------
# Retrieving Results for Index 166: Inhambane.
# Nearest Hotel Oceano.
# ------------
# Retrieving Results for Index 167: Bariloche.
# Nearest Hotel Hotel Patagonia.
# ------------
# Retrieving Results for Index 168: Panabá.
# Nearest Hotel Posada rosario.
# ------------
# Retrieving Results for Index 169: Clyde River.
# Nearest Hotel Qamaq Hotel.
# ------------
# Retrieving Results for Index 170: College.
# Nearest Hotel Pike's Waterfront Lodge.
# ------------
# Retrieving Results for Index 171: Okhotsk.
# Missing Results.
# ------------
# Retrieving Results for Index 172: Port Elizabeth.
# Nearest Hotel 39 On Nile Guest House.
# ------------
# Retrieving Results for Index 173: Yellowknife.
# Nearest Hotel The Explorer Hotel.
# ------------
# Retrieving Results for Index 174: Yerofey Pavlovich.
# Nearest Hotel lounges and warm parking.
# ------------
# Retrieving Results for Index 175: George Town.
# Nearest Hotel Cititel Penang.
# ------------
# Retrieving Results for Index 176: Amealco.
# Nearest Hotel Hotel Jose Maria.
# ------------
# Retrieving Results for Index 177: Ola.
# Missing Results.
# ------------
# Retrieving Results for Index 178: Bambous Virieux.
# Nearest Hotel Casa Tia Villa.
# ------------
# Retrieving Results for Index 179: Pedra Branca.
# Nearest Hotel Chácara Verçoza.
# ------------
# Retrieving Results for Index 180: Jaranwala.
# Nearest Hotel Dera Syed Sibt e Hassan.
# ------------
# Retrieving Results for Index 181: Tacuarembó.
# Nearest Hotel Complejo San Fructuoso.
# ------------
# Retrieving Results for Index 182: Shihezi.
# Nearest Hotel Home Inn Shihezi Dongwu Road Century Square.
# ------------
# Retrieving Results for Index 183: East London.
# Nearest Hotel Tu Casa.
# ------------
# Retrieving Results for Index 184: Arrondissement d'Ajaccio.
# Nearest Hotel Sole E Monte.
# ------------
# Retrieving Results for Index 185: Nārāyanganj.
# Nearest Hotel Ameer Hussain.
# ------------
# Retrieving Results for Index 186: Martapura.
# Nearest Hotel Montana Hotel Syariah.
# ------------
# Retrieving Results for Index 187: Caruray.
# Missing Results.
# ------------
# Retrieving Results for Index 188: Shimoda.
# Nearest Hotel Shimoda Tokyu Hotel.
# ------------
# Retrieving Results for Index 189: Zhanakorgan.
# Nearest Hotel "Ақпалас" қонақ үйі.
# ------------
# Retrieving Results for Index 190: Vaini.
# Nearest Hotel Keleti Beach Resort.
# ------------
# Retrieving Results for Index 191: Havelock.
# Nearest Hotel Sherwood Motel.
# ------------
# Retrieving Results for Index 192: Puerto Escondido.
# Nearest Hotel Aldea del Bazar Hotel and Spa.
# ------------
# Retrieving Results for Index 193: Charters Towers.
# Nearest Hotel Cattleman's Rest Motor Inn.
# ------------
# Retrieving Results for Index 194: Poum.
# Nearest Hotel Gîte kajeon.
# ------------
# Retrieving Results for Index 195: Krasnosel'kup.
# Nearest Hotel Krasnosel'kupnefteprodukt.
# ------------
# Retrieving Results for Index 196: Meulaboh.
# Nearest Hotel Kost Pria.
# ------------
# Retrieving Results for Index 197: Oranjestad.
# Nearest Hotel Divi Village Golf & Beach Resort.
# ------------
# Retrieving Results for Index 198: Geraldton.
# Nearest Hotel Broadwater Mariner Resort.
# ------------
# Retrieving Results for Index 199: Legnica.
# Nearest Hotel Qubus Hotel Legnica.
# ------------
# Retrieving Results for Index 200: Pemba.
# Nearest Hotel Guesthouse Samotina.
# ------------
# Retrieving Results for Index 201: Solnechnyy.
# Nearest Hotel Hotel complex Pastoral.
# ------------
# Retrieving Results for Index 202: Lodja.
# Missing Results.
# ------------
# Retrieving Results for Index 203: Luba.
# Missing Results.
# ------------
# Retrieving Results for Index 204: Mahébourg.
# Nearest Hotel Shandrani Beachcomber Resort & Spa.
# ------------
# Retrieving Results for Index 205: Nyurba.
# Nearest Hotel Gostinitsa Alrosa.
# ------------
# Retrieving Results for Index 206: The Valley.
# Nearest Hotel CeBlue Villas & Beach Resort.
# ------------
# Retrieving Results for Index 207: Tuy Hoa.
# Nearest Hotel CenDeluxe Hotel Tuy Hoa.
# ------------
# Retrieving Results for Index 208: Sorong.
# Nearest Hotel waigo splash hotel.
# ------------
# Retrieving Results for Index 209: Boddam.
# Nearest Hotel Palace Hotel.
# ------------
# Retrieving Results for Index 210: Melilla.
# Nearest Hotel Hotel Nacional.
# ------------
# Retrieving Results for Index 211: Kruisfontein.
# Nearest Hotel Oyster Bay House Rental.
# ------------
# Retrieving Results for Index 212: Port Blair.
# Nearest Hotel Welcomhotel By ITC Hotels, Bay Island, Port Blair.
# ------------
# Retrieving Results for Index 213: Falam.
# Nearest Hotel Falang Government Guesthouse.
# ------------
# Retrieving Results for Index 214: Aksu.
# Nearest Hotel Pudong Holiday Hotel.
# ------------
# Retrieving Results for Index 215: Saurimo.
# Nearest Hotel Hotel Kawissa Saurimo.
# ------------
# Retrieving Results for Index 216: Cap-aux-Meules.
# Nearest Hotel Auberge Madeli.
# ------------
# Retrieving Results for Index 217: Hongjiang.
# Nearest Hotel 洪江大酒店.
# ------------
# Retrieving Results for Index 218: Midland.
# Nearest Hotel DoubleTree by Hilton Hotel Midland Plaza.
# ------------
# Retrieving Results for Index 219: Ixtapa.
# Nearest Hotel Hotel Plaza Providencia.
# ------------
# Retrieving Results for Index 220: Trincomalee.
# Nearest Hotel Welcombe Hotel.
# ------------
# Retrieving Results for Index 221: Makakilo City.
# Nearest Hotel Marriott's Ko Olina Beach Club.
# ------------
# Retrieving Results for Index 222: Ust-Kuyga.
# Missing Results.
# ------------
# Retrieving Results for Index 223: Tadine.
# Missing Results.
# ------------
# Retrieving Results for Index 224: Ulaanbaatar.
# Nearest Hotel The Blue Sky Hotel and Tower.
# ------------
# Retrieving Results for Index 225: Hong Kong.
# Nearest Hotel Mini Hotel Central.
# ------------
# Retrieving Results for Index 226: Pobé.
# Nearest Hotel Hôtel Étoile d'Or de Pobé.
# ------------
# Retrieving Results for Index 227: Ribeira Grande.
# Nearest Hotel Quinta da Meia Eira.
# ------------
# Retrieving Results for Index 228: Anking.
# Nearest Hotel Hongtian Hotel.
# ------------
# Retrieving Results for Index 229: Joshīmath.
# Nearest Hotel Shivalik Camps & Resort.
# ------------
# Retrieving Results for Index 230: La Palma.
# Nearest Hotel La Quinta Inn & Suites by Wyndham Buena Park.
# ------------
# Retrieving Results for Index 231: Saint-Augustin.
# Missing Results.
# ------------
# Retrieving Results for Index 232: Tuktoyaktuk.
# Nearest Hotel End of The Road Ltd..
# ------------
# Retrieving Results for Index 233: Cabo San Lucas.
# Nearest Hotel Hotel Tesoro Los Cabos.
# ------------
# Retrieving Results for Index 234: Okha.
# Nearest Hotel Империя.
# ------------
# Retrieving Results for Index 235: Yangi Marg`ilon.
# Nearest Hotel Ikathouse.
# ------------
# Retrieving Results for Index 236: Beringovskiy.
# Nearest Hotel Beringgorski.
# ------------
# Retrieving Results for Index 237: Santa Maria.
# Nearest Hotel Hotel Morotin.
# ------------
# Retrieving Results for Index 238: Ajdabiya.
# Nearest Hotel Almadina Hotel.
# ------------
# Retrieving Results for Index 239: Nakanojōmachi.
# Nearest Hotel 山木屋旅館.
# ------------
# Retrieving Results for Index 240: Faya.
# Nearest Hotel املاك خالد الشعشوع.
# ------------
# Retrieving Results for Index 241: Berbera.
# Nearest Hotel IBCO REAL ESTATE PROPERTY.
# ------------
# Retrieving Results for Index 242: Kushima.
# Nearest Hotel Hanaoka.
# ------------
# Retrieving Results for Index 243: Dikson.
# Missing Results.
# ------------
# Retrieving Results for Index 244: Banjar.
# Nearest Hotel The Hamsa Resort.
# ------------
# Retrieving Results for Index 245: Butaritari.
# Nearest Hotel Isles Sunset Lodge.
# ------------
# Retrieving Results for Index 246: Lodwar.
# Nearest Hotel Solmar Gracious Hotel.
# ------------
# Retrieving Results for Index 247: Kibre Mengist.
# Nearest Hotel Gunbuur Motel.
# ------------
# Retrieving Results for Index 248: Verkhnevilyuysk.
# Nearest Hotel Gostinitsa Mila.
# ------------
# Retrieving Results for Index 249: Leningradskiy.
# Nearest Hotel Gostinitsa.
# ------------
# Retrieving Results for Index 250: Thompson.
# Nearest Hotel Burntwood Hotel.
# ------------
# Retrieving Results for Index 251: Hobart.
# Nearest Hotel Mantra on Collins Hobart.
# ------------
# Retrieving Results for Index 252: Goderich.
# Nearest Hotel Harmony Inn.
# ------------
# Retrieving Results for Index 253: Bang Saphan.
# Nearest Hotel Ladawan Boutique Hotel.
# ------------
# Retrieving Results for Index 254: Anloga.
# Nearest Hotel Pin Drop Hotel.
# ------------
# Retrieving Results for Index 255: Menongue.
# Nearest Hotel Ritz Lauca.
# ------------
# Retrieving Results for Index 256: Labuhan.
# Nearest Hotel PT PPI Lamongan Tambak C.
# ------------
# Retrieving Results for Index 257: Namatanai.
# Nearest Hotel Seagulls Inn Namatani.
# ------------
# Retrieving Results for Index 258: Chālūs.
# Nearest Hotel نظام مهندسي ساختمان چالوس.
# ------------
# Retrieving Results for Index 259: Petropavlovsk-Kamchatskiy.
# Nearest Hotel The Hotel Petropavlovsky.
# ------------
# Retrieving Results for Index 260: Władysławowo.
# Nearest Hotel Gwiazda Morza Resort SPA&SPORT.
# ------------
# Retrieving Results for Index 261: Peleduy.
# Nearest Hotel Гостиница «Уют».
# ------------
# Retrieving Results for Index 262: Esperance.
# Nearest Hotel Hospitality Esperance.
# ------------
# Retrieving Results for Index 263: Liverpool.
# Nearest Hotel Premier Inn Liverpool City Centre (Moorfields) hotel.
# ------------
# Retrieving Results for Index 264: Bima.
# Nearest Hotel Lambitu Hotel.
# ------------
# Retrieving Results for Index 265: Zeya.
# Nearest Hotel Kapital Inn.
# ------------
# Retrieving Results for Index 266: Slave Lake.
# Nearest Hotel Super 8 by Wyndham Slave Lake AB.
# ------------
# Retrieving Results for Index 267: Linqiong.
# Nearest Hotel Tianlun Tanxianglou Hotel.
# ------------
# Retrieving Results for Index 268: Bilma.
# Nearest Hotel Expeditions Ténére voyages.
# ------------
# Retrieving Results for Index 269: Narsaq.
# Nearest Hotel Narsaq Kayak Hostel.
# ------------
# Retrieving Results for Index 270: Pangnirtung.
# Nearest Hotel Kilabuk Lodge.
# ------------
# Retrieving Results for Index 271: Tabou.
# Nearest Hotel hotêl doufoulougou.
# ------------
# Retrieving Results for Index 272: Ballina.
# Nearest Hotel Ramada Hotel & Suites by Wyndham Ballina Byron.
# ------------
# Retrieving Results for Index 273: Atambua.
# Nearest Hotel Pastori 1 Jemaat Polycarpus.
# ------------
# Retrieving Results for Index 274: Ewo.
# Nearest Hotel Residence Elonda Ewo.
# ------------
# Retrieving Results for Index 275: Mount Isa.
# Nearest Hotel ibis Styles Mt Isa Verona.
# ------------
# Retrieving Results for Index 276: Lamar.
# Nearest Hotel Kings Inn Paris TX.
# ------------
# Retrieving Results for Index 277: Itaporanga.
# Nearest Hotel Hotel Rainha do Vale.
# ------------
# Retrieving Results for Index 278: Tura.
# Nearest Hotel Hotel RIKMAN Continental.
# ------------
# Retrieving Results for Index 279: Coquimbo.
# Nearest Hotel Punto de encuentro.
# ------------
# Retrieving Results for Index 280: Kaitangata.
# Nearest Hotel Kaitangata Motor Camp.
# ------------
# Retrieving Results for Index 281: Bairiki Village.
# Nearest Hotel Tarawa Boutique Hotel.
# ------------
# Retrieving Results for Index 282: Palmer.
# Nearest Hotel Wedgewood Motel.
# ------------
# Retrieving Results for Index 283: Karratha.
# Nearest Hotel ibis Styles Karratha.
# ------------
# Retrieving Results for Index 284: Humberto de Campos.
# Nearest Hotel Pousada do Cabeça.
# ------------
# Retrieving Results for Index 285: Fortuna.
# Nearest Hotel Super 8 by Wyndham Fortuna.
# ------------
# Retrieving Results for Index 286: Yima.
# Nearest Hotel Yima Hotel.
# ------------
# Retrieving Results for Index 287: Saint-Pierre.
# Nearest Hotel Lindsey Hôtel.
# ------------
# Retrieving Results for Index 288: Mehamn.
# Nearest Hotel Mehamn Arctic Hotel AS.
# ------------
# Retrieving Results for Index 289: Cherkasskoye.
# Missing Results.
# ------------
# Retrieving Results for Index 290: Kalmunai.
# Nearest Hotel VS Villa.
# ------------
# Retrieving Results for Index 291: Samaná.
# Nearest Hotel The Bannister - Hotel & Yacht Club.
# ------------
# Retrieving Results for Index 292: Selenduma.
# Missing Results.
# ------------
# Retrieving Results for Index 293: Hamilton.
# Nearest Hotel Six Acres Bed & Breakfast.
# ------------
# Retrieving Results for Index 294: Markova.
# Nearest Hotel Vas.VOM.
# ------------
# Retrieving Results for Index 295: Kindu.
# Nearest Hotel Résidence Okanda.
# ------------
# Retrieving Results for Index 296: Gizo Government Station.
# Nearest Hotel Imagination Island.
# ------------
# Retrieving Results for Index 297: Ruwi.
# Nearest Hotel Al Falaj Hotel.
# ------------
# Retrieving Results for Index 298: Albacete.
# Missing Results.
# ------------
# Retrieving Results for Index 299: Mokhsogollokh.
# Missing Results.
# ------------
# Retrieving Results for Index 300: Goes.
# Nearest Hotel Hotel Terminus.
# ------------
# Retrieving Results for Index 301: Henties Bay.
# Nearest Hotel Fishermans Guest House.
# ------------
# Retrieving Results for Index 302: Mount Gambier.
# Nearest Hotel The Commodore.
# ------------
# Retrieving Results for Index 303: Alofi.
# Nearest Hotel Taloa Heights.
# ------------
# Retrieving Results for Index 304: Dingle.
# Nearest Hotel SEGAYA PROPERTY.
# ------------
# Retrieving Results for Index 305: Povenets.
# Nearest Hotel Eko Otel' Bol'shaya Medveditsa.
# ------------
# Retrieving Results for Index 306: Lagoa Formosa.
# Nearest Hotel Lagoa Hotel.
# ------------
# Retrieving Results for Index 307: Bentiu.
# Nearest Hotel Mandela hôtel.
# ------------
# Retrieving Results for Index 308: Umm Kaddadah.
# Missing Results.
# ------------
# Retrieving Results for Index 309: Chicama.
# Nearest Hotel Balihai Bungalows.
# ------------
# Retrieving Results for Index 310: Vestmannaeyjar.
# Nearest Hotel Glamping & Camping.
# ------------
# Retrieving Results for Index 311: Luancheng.
# Nearest Hotel Shell Hebei Shijiazhuang Luancheng Xinyuan Road Hotel.
# ------------
# Retrieving Results for Index 312: Gushikawa.
# Nearest Hotel Kirari Guest House.
# ------------
# Retrieving Results for Index 313: Nome.
# Nearest Hotel Dredge 7 Inn.
# ------------
# Retrieving Results for Index 314: Stokmarknes.
# Nearest Hotel Vesterålen Kysthotell.
# ------------
# Retrieving Results for Index 315: Gladstone.
# Nearest Hotel Highpoint International.
# ------------
# Retrieving Results for Index 316: Nelson Bay.
# Nearest Hotel Mantra Nelson Bay.
# ------------
# Retrieving Results for Index 317: Haines Junction.
# Nearest Hotel Parkside Inn.
# ------------
# Retrieving Results for Index 318: Turukhansk.
# Nearest Hotel ООО "Туруханская пушнина".
# ------------
# Retrieving Results for Index 319: Faanui.
# Nearest Hotel Bora-Bora Pearl Beach Resort & Spa.
# ------------
# Retrieving Results for Index 320: Buritizeiro.
# Nearest Hotel Santos Palace Hotel.
# ------------
# Retrieving Results for Index 321: Andenes.
# Nearest Hotel Hotell Marena.
# ------------
# Retrieving Results for Index 322: Port Alberni.
# Nearest Hotel Somass Motel & RV.
# ------------
# Retrieving Results for Index 323: Vilhena.
# Nearest Hotel Hotel Mirage.
# ------------
# Retrieving Results for Index 324: Laguna.
# Nearest Hotel Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel.
# ------------
# Retrieving Results for Index 325: Seoul.
# Nearest Hotel Lotte Hotel Seoul.
# ------------
# Retrieving Results for Index 326: Alta Gracia.
# Nearest Hotel Hotel Ritz.
# ------------
# Retrieving Results for Index 327: Diffa.
# Nearest Hotel ProDAF/Diffa.
# ------------
# Retrieving Results for Index 328: Guerrero Negro.
# Nearest Hotel Casa Laguna, Bed & Breakfast.
# ------------
# Retrieving Results for Index 329: Camacupa.
# Nearest Hotel seviremde seni.
# ------------
# Retrieving Results for Index 330: Erzin.
# Nearest Hotel Artemis Otel.
# ------------
# Retrieving Results for Index 331: San Patricio.
# Nearest Hotel Motel 6 Sinton, TX.
# ------------
# Retrieving Results for Index 332: Boyolangu.
# Nearest Hotel Yos ega cv.
# ------------
# Retrieving Results for Index 333: Yashkul'.
# Nearest Hotel Bon Voyazh.
# ------------
# Retrieving Results for Index 334: Santa Cruz de la Sierra.
# Nearest Hotel Aviador Hotel Boutique.
# ------------
# Retrieving Results for Index 335: San Andrés.
# Nearest Hotel Hotel Arena Blanca.
# ------------
# Retrieving Results for Index 336: Plettenberg Bay.
# Nearest Hotel Thanda Vista B&B.
# ------------
# Retrieving Results for Index 337: Hannibal.
# Nearest Hotel Country Hearth Inn Hannibal.
# ------------
# Retrieving Results for Index 338: Vila Franca do Campo.
# Nearest Hotel Pestana Bahia Praia.
# ------------
# Retrieving Results for Index 339: Mizdah.
# Nearest Hotel محمدالمبروك الاريقط.
# ------------
# Retrieving Results for Index 340: Muros.
# Nearest Hotel Apartment Av. Castelao.
# ------------
# Retrieving Results for Index 341: Olinda.
# Nearest Hotel Hotel Albergue de Olinda.
# ------------
# Retrieving Results for Index 342: Aksarka.
# Missing Results.
# ------------
# Retrieving Results for Index 343: Shirokiy.
# Missing Results.
# ------------
# Retrieving Results for Index 344: Morro Bay.
# Nearest Hotel Inn at Morro Bay.
# ------------
# Retrieving Results for Index 345: Kushiro.
# Nearest Hotel Toyoko Inn Kushiro Jujigai.
# ------------
# Retrieving Results for Index 346: Araouane.
# Missing Results.
# ------------
# Retrieving Results for Index 347: Burnie.
# Nearest Hotel Beachfront Voyager Motor Inn.
# ------------
# Retrieving Results for Index 348: Abéché.
# Nearest Hotel Assaleh Hamdan Haroune.
# ------------
# Retrieving Results for Index 349: Ust-Nera.
# Nearest Hotel Hotel Ust-Nera.
# ------------
# Retrieving Results for Index 350: Pogar.
# Nearest Hotel Gostinitsa "U Gamleta".
# ------------
# Retrieving Results for Index 351: Borba.
# Nearest Hotel Hotel da Amazônia.
# ------------
# Retrieving Results for Index 352: Eyl.
# Nearest Hotel Amiin Hotel.
# ------------
# Retrieving Results for Index 353: Khambhāt.
# Nearest Hotel Anand.
# ------------
# Retrieving Results for Index 354: Lavrentiya.
# Missing Results.
# ------------
# Retrieving Results for Index 355: Port Moresby.
# Nearest Hotel Lamana Hotel (Port Moresby).
# ------------
# Retrieving Results for Index 356: Lagoa.
# Nearest Hotel Casa Das Faias.
# ------------
# Retrieving Results for Index 357: Parabel'.
# Nearest Hotel Housing Complex Gazprom Transgaz Tomsk.
# ------------
# Retrieving Results for Index 358: La Santisima Trinidad.
# Nearest Hotel Hotel Piesta.
# ------------
# Retrieving Results for Index 359: Nassau.
# Nearest Hotel Hilton Garden Inn Westbury.
# ------------
# Retrieving Results for Index 360: Saskylakh.
# Missing Results.
# ------------
# Retrieving Results for Index 361: Kuruman.
# Nearest Hotel Cornerstone Guest House.
# ------------
# Retrieving Results for Index 362: Kuantan.
# Nearest Hotel Hotel Sentral Kuantan.
# ------------
# Retrieving Results for Index 363: Tingo María.
# Nearest Hotel Hospedaje Paraíso.
# ------------
# Retrieving Results for Index 364: Robertsport.
# Nearest Hotel Kwepunha Retreat.
# ------------
# Retrieving Results for Index 365: Härnösand.
# Nearest Hotel First Hotel Stadt.
# ------------
# Retrieving Results for Index 366: New Baltimore.
# Nearest Hotel Northpointe Shores RV Resort.
# ------------
# Retrieving Results for Index 367: Cayenne.
# Nearest Hotel Hôtel Le Dronmi.
# ------------
# Retrieving Results for Index 368: Nísia Floresta.
# Nearest Hotel Rancho Crepusculo.
# ------------
# Retrieving Results for Index 369: Shitanjing.
# Missing Results.
# ------------
# Retrieving Results for Index 370: Presidente Epitácio.
# Nearest Hotel Hotel Itaverá.
# ------------
# Retrieving Results for Index 371: El Salvador.
# Nearest Hotel Chico's Ranch.
# ------------
# Retrieving Results for Index 372: Castlegar.
# Nearest Hotel Cozy Pines Motel.
# ------------
# Retrieving Results for Index 373: Saint George.
# Nearest Hotel Best Western Plus Abbey Inn.
# ------------
# Retrieving Results for Index 374: Valguarnera Caropepe.
# Nearest Hotel B&B Panoramic.
# ------------
# Retrieving Results for Index 375: Medicine Hat.
# Nearest Hotel Sun Dek Motel.
# ------------
# Retrieving Results for Index 376: Zhigansk.
# Nearest Hotel Gostinichnyy Kompleks Aylgy.
# ------------
# Retrieving Results for Index 377: Chumikan.
# Nearest Hotel Fortuna.
# ------------
# Retrieving Results for Index 378: Kilkis.
# Nearest Hotel Habitat Hotel.
# ------------
# Retrieving Results for Index 379: Inongo.
# Nearest Hotel Hotel Du Lac.
# ------------
# Retrieving Results for Index 380: San Juan.
# Nearest Hotel Hotel Provincial.
# ------------
# Retrieving Results for Index 381: Umluj.
# Nearest Hotel Moon light Furnished Units.
# ------------
# Retrieving Results for Index 382: Kutum.
# Nearest Hotel Dibbo areaمنطقة دبو.
# ------------
# Retrieving Results for Index 383: Américo Brasiliense.
# Nearest Hotel Santuário da Fé.
# ------------
# Retrieving Results for Index 384: Yulara.
# Nearest Hotel Desert Gardens Hotel - Ayers Rock Resort.
# ------------
# Retrieving Results for Index 385: Granada.
# Nearest Hotel HOTEL REINA CRISTINA.
# ------------
# Retrieving Results for Index 386: Sambava.
# Nearest Hotel Melrose.
# ------------
# Retrieving Results for Index 387: Elizabeth City.
# Nearest Hotel Hampton Inn Elizabeth City.
# ------------
# Retrieving Results for Index 388: Hofn.
# Nearest Hotel Hótel Höfn.
# ------------
# Retrieving Results for Index 389: Celestún.
# Nearest Hotel Posada Lilia.
# ------------
# Retrieving Results for Index 390: Salé.
# Nearest Hotel Hôtel Mercure Rabat Sheherazade.
# ------------
# Retrieving Results for Index 391: Acapulco de Juárez.
# Nearest Hotel HS Hotsson Smart Acapulco.
# ------------
# Retrieving Results for Index 392: Polovinnoye.
# Missing Results.
# ------------
# Retrieving Results for Index 393: Kastraki.
# Nearest Hotel Dellas Boutique Hotel.
# ------------
# Retrieving Results for Index 394: Brewster.
# Nearest Hotel Heidi's Inn.
# ------------
# Retrieving Results for Index 395: Sitka.
# Nearest Hotel Westmark Sitka.
# ------------
# Retrieving Results for Index 396: Te Anau.
# Nearest Hotel Kingsgate Hotel Te Anau.
# ------------
# Retrieving Results for Index 397: Almancil.
# Nearest Hotel Aquashow Park.
# ------------
# Retrieving Results for Index 398: Ushumun.
# Missing Results.
# ------------
# Retrieving Results for Index 399: Alyangula.
# Nearest Hotel Groote Eylandt Lodge.
# ------------
# Retrieving Results for Index 400: Fukuechō.
# Nearest Hotel Goto Guesthouse Utojuku & SA Car Rental.
# ------------
# Retrieving Results for Index 401: Khomutovo.
# Nearest Hotel Almaznaia,48.
# ------------
# Retrieving Results for Index 402: Newport.
# Nearest Hotel ibis budget Newport.
# ------------
# Retrieving Results for Index 403: Pevek.
# Nearest Hotel Severnoye Zoloto.
# ------------
# Retrieving Results for Index 404: Pithorāgarh.
# Nearest Hotel Hipostel Pithoragarh (Cafe Morrison).
# ------------
# Retrieving Results for Index 405: Cascais.
# Nearest Hotel Hotel Vila Galé Cascais.
# ------------
# Retrieving Results for Index 406: Benjamin Constant.
# Nearest Hotel CASA AVALIADA.
# ------------
# Retrieving Results for Index 407: Stornoway.
# Nearest Hotel Caladh Inn.
# ------------
# Retrieving Results for Index 408: Grindavik.
# Nearest Hotel Northern Light Inn & Max's Restaurant.
# ------------
# Retrieving Results for Index 409: Ilo.
# Nearest Hotel Torreblanca Hotel.
# ------------
# Retrieving Results for Index 410: Teahupoo.
# Nearest Hotel Vanira Lodge.
# ------------
# Retrieving Results for Index 411: Beaupré.
# Nearest Hotel Hébergement Mont-Sainte-Anne.
# ------------
# Retrieving Results for Index 412: Komsomolsk-on-Amur.
# Nearest Hotel Siti.
# ------------
# Retrieving Results for Index 413: Abhā.
# Nearest Hotel Abha Hotel.
# ------------
# Retrieving Results for Index 414: Izhma.
# Missing Results.
# ------------
# Retrieving Results for Index 415: Maputo.
# Nearest Hotel Pestana Rovuma.
# ------------
# Retrieving Results for Index 416: Taltal.
# Nearest Hotel Residencial Karime.
# ------------
# Retrieving Results for Index 417: Contramaestre.
# Nearest Hotel Hotel Caribeño.
# ------------
# Retrieving Results for Index 418: Korla.
# Nearest Hotel Gulisitan Hotel.
# ------------
# Retrieving Results for Index 419: Elmadağ.
# Nearest Hotel buluş apartmanı.
# ------------
# Retrieving Results for Index 420: Suoyarvi.
# Nearest Hotel Mini-Hotel Comfort.
# ------------
# Retrieving Results for Index 421: Palekastro.
# Nearest Hotel Marina Village.
# ------------
# Retrieving Results for Index 422: Bilibino.
# Nearest Hotel Gostinitsa Severyanka.
# ------------
# Retrieving Results for Index 423: Jacmel.
# Nearest Hotel Historic Hotel Florita.
# ------------
# Retrieving Results for Index 424: Los Llanos de Aridane.
# Nearest Hotel Valle Aridane.
# ------------
# Retrieving Results for Index 425: São Félix do Xingu.
# Nearest Hotel Rio Xingu Camping.
# ------------
# Retrieving Results for Index 426: Szydłowiec.
# Nearest Hotel Hotel Oleńka.
# ------------
# Retrieving Results for Index 427: Hambantota.
# Nearest Hotel Bungalow 63.
# ------------
# Retrieving Results for Index 428: Ambon City.
# Nearest Hotel Swiss-Belhotel Ambon.
# ------------
# Retrieving Results for Index 429: Koutiala.
# Nearest Hotel Hotel La Chaumiere.
# ------------
# Retrieving Results for Index 430: Daru.
# Nearest Hotel Daru Lodge.
# ------------
# Retrieving Results for Index 431: Bud.
# Nearest Hotel Ted McQuinn Trust.
# ------------
# Retrieving Results for Index 432: Koumra.
# Nearest Hotel Yamtoide house koumra.
# ------------
# Retrieving Results for Index 433: Juegang.
# Nearest Hotel Rudong Y Hotel.
# ------------
# Retrieving Results for Index 434: Linfen.
# Nearest Hotel Suoxing Hotel.
# ------------
# Retrieving Results for Index 435: Westport.
# Nearest Hotel The Westport Inn.
# ------------
# Retrieving Results for Index 436: Vila Velha.
# Nearest Hotel Quality Suites Vila Velha.
# ------------
# Retrieving Results for Index 437: Morondava.
# Nearest Hotel La Case Bambou.
# ------------
# Retrieving Results for Index 438: Eenhana.
# Nearest Hotel Hotel Litu.
# ------------
# Retrieving Results for Index 439: Agadez.
# Missing Results.
# ------------
# Retrieving Results for Index 440: Carballo.
# Nearest Hotel Pazo do Souto.
# ------------
# Retrieving Results for Index 441: Padang.
# Nearest Hotel Mercure Padang.
# ------------
# Retrieving Results for Index 442: Kemin.
# Nearest Hotel Hotel Kok-Oirok.
# ------------
# Retrieving Results for Index 443: La Ronge.
# Nearest Hotel Northland Motor Hotel.
# ------------
# Retrieving Results for Index 444: Fergus Falls.
# Nearest Hotel AmericInn by Wyndham Fergus Falls Conference Center.
# ------------
# Retrieving Results for Index 445: Eugene.
# Nearest Hotel Valley River Inn.
# ------------
# Retrieving Results for Index 446: Fujimi.
# Nearest Hotel 288HOTEL.
# ------------
# Retrieving Results for Index 447: Zhezkazgan.
# Nearest Hotel Hotel Zumrat.
# ------------
# Retrieving Results for Index 448: Kuah.
# Nearest Hotel Azio Hotel.
# ------------
# Retrieving Results for Index 449: Alice Springs.
# Nearest Hotel Desert Palms Alice Springs.
# ------------
# Retrieving Results for Index 450: Lagunas.
# Nearest Hotel Hospedaje Eco.
# ------------
# Retrieving Results for Index 451: Raudeberg.
# Nearest Hotel Nordre Silda..
# ------------
# Retrieving Results for Index 452: Mayumba.
# Nearest Hotel LIKWALE LODGE.
# ------------
# Retrieving Results for Index 453: Mabaruma.
# Nearest Hotel Monty Brooms Guest House.
# ------------
# Retrieving Results for Index 454: Karasburg.
# Nearest Hotel Hoon's Selfcatering.
# ------------
# Retrieving Results for Index 455: Stromness.
# Nearest Hotel The Old Smokery.
# ------------
# Retrieving Results for Index 456: Kudahuvadhoo.
# Nearest Hotel Niyama Private Islands Maldives.
# ------------
# Retrieving Results for Index 457: Havøysund.
# Nearest Hotel Arctic View Glamping & Restaurant.
# ------------
# Retrieving Results for Index 458: Galle.
# Nearest Hotel Amangalla.
# ------------
# Retrieving Results for Index 459: Tawang Town.
# Nearest Hotel Hotel Mount View.
# ------------
# Retrieving Results for Index 460: Paamiut.
# Nearest Hotel Hotel Ivaana.
# ------------
# Retrieving Results for Index 461: Puerto Maldonado.
# Nearest Hotel Wasai Hotel.
# ------------
# Retrieving Results for Index 462: Dawlatabad.
# Nearest Hotel WASIM ASGAR KHAN.
# ------------
# Retrieving Results for Index 463: Laas.
# Nearest Hotel Pension Feldgärtenhof.
# ------------
# Retrieving Results for Index 464: Toamasina.
# Nearest Hotel Hotel H1.
# ------------
# Retrieving Results for Index 465: Fare.
# Nearest Hotel Maitai Lapita Village Huahine.
# ------------
# Retrieving Results for Index 466: Chemin Grenier.
# Nearest Hotel Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 467: Kem'.
# Nearest Hotel Mini-hotel "Kem".
# ------------
# Retrieving Results for Index 468: Sarh.
# Nearest Hotel Domicile 1sur le goudron.
# ------------
# Retrieving Results for Index 469: Mosjøen.
# Nearest Hotel Fru Haugans Hotel.
# ------------
# Retrieving Results for Index 470: Straumen.
# Nearest Hotel Jægtvolden Fjordhotell.
# ------------
# Retrieving Results for Index 471: Moroto.
# Nearest Hotel Kara-Tunga, Karamoja Safari Camp.
# ------------
# Retrieving Results for Index 472: Pokosnoye.
# Missing Results.
# ------------
# Retrieving Results for Index 473: Departamento de Maldonado.
# Nearest Hotel La Cimarrona.
# ------------
# Retrieving Results for Index 474: Coro.
# Nearest Hotel Federal.
# ------------
# Retrieving Results for Index 475: Birao.
# Missing Results.
# ------------
# Retrieving Results for Index 476: Orlik.
# Nearest Hotel Gostevoy Dom Mini Gostinitsa.
# ------------
# Retrieving Results for Index 477: Harper.
# Nearest Hotel Screensaver.
# ------------
# Retrieving Results for Index 478: Minsk.
# Nearest Hotel Minsk Hotel.
# ------------
# Retrieving Results for Index 479: Kavaratti.
# Nearest Hotel Hotels in Lakshadweep Islands.
# ------------
# Retrieving Results for Index 480: Nekhayevskiy.
# Nearest Hotel Gostevoy Dom St. Nekhayevskaya Zhil'yo Posutochno.
# ------------
# Retrieving Results for Index 481: Pryyutivka.
# Nearest Hotel Многоквартирный Дом по адресу: Войновское шосе 12,.
# ------------
# Retrieving Results for Index 482: Yar-Sale.
# Nearest Hotel Yalemd.
# ------------
# Retrieving Results for Index 483: Jining.
# Nearest Hotel Yunhe Star Hotel.
# ------------
# Retrieving Results for Index 484: Krasnoarmeysk.
# Nearest Hotel Hotel "Your home-Balzer".
# ------------
# Retrieving Results for Index 485: Pisco.
# Nearest Hotel Hotel San Isidro Oficial.
# ------------
# Retrieving Results for Index 486: Port-Gentil.
# Nearest Hotel Fengshui Residence.
# ------------
# Retrieving Results for Index 487: Yagoua.
# Nearest Hotel Sahel Hotel.
# ------------
# Retrieving Results for Index 488: Yārāda.
# Nearest Hotel Vishranti.
# ------------
# Retrieving Results for Index 489: Ulaangom.
# Nearest Hotel Achit Nuur Hotel & Restaurant.
# ------------
# Retrieving Results for Index 490: Merauke.
# Missing Results.
# ------------
# Retrieving Results for Index 491: Buckeye.
# Nearest Hotel Buckeye Motor Hotel.
# ------------
# Retrieving Results for Index 492: Blagoyevo.
# Missing Results.
# ------------
# Retrieving Results for Index 493: Betsiamites.
# Missing Results.
# ------------
# Retrieving Results for Index 494: Quelimane.
# Nearest Hotel Hotel Flamingo.
# ------------
# Retrieving Results for Index 495: San Policarpo.
# Nearest Hotel Agapita M. Nicart.
# ------------
# Retrieving Results for Index 496: Meadow Lake.
# Nearest Hotel TumbleWeed RV Park.
# ------------
# Retrieving Results for Index 497: Sokoni.
# Nearest Hotel Ujamaa Beach Resort.
# ------------
# Retrieving Results for Index 498: Dogbo.
# Nearest Hotel Maison des visiteurs / auberge chez ESI ONG/ pro dogbo e.V..
# ------------
# Retrieving Results for Index 499: Shōbara.
# Nearest Hotel Kampo-no-sato Shobara.
# ------------
# Retrieving Results for Index 500: Lorengau.
# Nearest Hotel Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for Index 501: La Asuncion.
# Nearest Hotel Colinas de Matasiete.
# ------------
# Retrieving Results for Index 502: Novyye Gorki.
# Missing Results.
# ------------
# Retrieving Results for Index 503: Wencheng.
# Nearest Hotel Ruyi Hostel.
# ------------
# Retrieving Results for Index 504: Balclutha.
# Nearest Hotel Hotel South Otago.
# ------------
# Retrieving Results for Index 505: Kidal.
# Missing Results.
# ------------
# Retrieving Results for Index 506: Konëvo.
# Missing Results.
# ------------
# Retrieving Results for Index 507: Lubumbashi.
# Nearest Hotel Glo Flats.
# ------------
# Retrieving Results for Index 508: Talaya.
# Missing Results.
# ------------
# Retrieving Results for Index 509: Pandamatenga.
# Nearest Hotel Wildtrack Safaris Eco Lodge.
# ------------
# Retrieving Results for Index 510: Itarema.
# Nearest Hotel Sea Lounge! Bar, Club & Restaurant.
# ------------
# Retrieving Results for Index 511: Soyo.
# Nearest Hotel Hotel Mpampa.
# ------------
# Retrieving Results for Index 512: Santa Cruz de Barahona.
# Nearest Hotel Hotel Caribe.
# ------------
# Retrieving Results for Index 513: Gazojak.
# Nearest Hotel In gowy adamlaryñ yaśayan oyi.
# ------------
# Retrieving Results for Index 514: Fairbanks.
# Nearest Hotel Westmark Fairbanks Hotel & Conference Center.
# ------------
# Retrieving Results for Index 515: Rudnya.
# Nearest Hotel Paradoks.
# ------------
# Retrieving Results for Index 516: Naze.
# Nearest Hotel オーベルジュ・アガルイ.
# ------------
# Retrieving Results for Index 517: Moorhead.
# Nearest Hotel Courtyard by Marriott Fargo Moorhead, MN.
# ------------
# Retrieving Results for Index 518: Wattegama.
# Missing Results.
# ------------
# Retrieving Results for Index 519: Vanimo.
# Nearest Hotel Vahmoneh Lodge Vanimo.
# ------------
# Retrieving Results for Index 520: San Jose.
# Nearest Hotel The Westin San Jose.
# ------------
# Retrieving Results for Index 521: Sisimiut.
# Nearest Hotel Hotel Sisimiut.
# ------------
# Retrieving Results for Index 522: Esim.
# Nearest Hotel Axim Beach Resort And Spa.
# ------------
# Retrieving Results for Index 523: Campo Grande.
# Nearest Hotel Hotel Harbor Self Buriti Suítes Campo Grande.
# ------------
# Retrieving Results for Index 524: Nador.
# Nearest Hotel Hôtel La Giralda.
# ------------
# Retrieving Results for Index 525: Chlórakas.
# Nearest Hotel Elysium Hotel.
# ------------
# Retrieving Results for Index 526: Sovetskiy.
# Nearest Hotel Apartment on Kievskaya 29.
# ------------
# Retrieving Results for Index 527: Tarnów.
# Nearest Hotel Hotel Tarnovia.
# ------------
# Retrieving Results for Index 528: Morón.
# Nearest Hotel Hotel Morón.
# ------------
# Retrieving Results for Index 529: Denpasar.
# Nearest Hotel ASTON Denpasar Hotel & Convention Center.
# ------------
# Retrieving Results for Index 530: Karatuzskoye.
# Missing Results.
# ------------
# Retrieving Results for Index 531: Kayes.
# Missing Results.
# ------------
# Retrieving Results for Index 532: Usinsk.
# Nearest Hotel Dobro Pozhalovaty.
# ------------
# Retrieving Results for Index 533: Manono.
# Nearest Hotel Hotel hewa bora.
# ------------
# Retrieving Results for Index 534: Dzerzhinsk.
# Nearest Hotel Hotel Druzhba.
# ------------
# Retrieving Results for Index 535: Bundaberg.
# Nearest Hotel Takalvan Motel.
# ------------
# Retrieving Results for Index 536: Huilong.
# Nearest Hotel Hilton Garden Inn Qidong.
# ------------
# Retrieving Results for Index 537: Oranjemund.
# Nearest Hotel The Fisherman's Cove.
# ------------
# Retrieving Results for Index 538: Gangānagar.
# Nearest Hotel SPOT ON 72525 Govind Guest House.
# ------------
# Retrieving Results for Index 539: Algiers.
# Nearest Hotel Sofitel Algiers Hamma Garden.
# ------------
# Retrieving Results for Index 540: Portland.
# Nearest Hotel Embassy Suites by Hilton Portland Downtown.
# ------------
# Retrieving Results for Index 541: Bontang.
# Nearest Hotel KOPKAR Hotel Bintang Sintuk.
# ------------
# Retrieving Results for Index 542: Road Town.
# Nearest Hotel ZINGARA 76ft Catamaran, full crew-all included.
# ------------
# Retrieving Results for Index 543: Mildura.
# Nearest Hotel Mercure Hotel Mildura.
# ------------
# Retrieving Results for Index 544: Ramsgate.
# Nearest Hotel The Pegwell Bay Hotel.
# ------------
# Retrieving Results for Index 545: Bonthe.
# Nearest Hotel Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 546: Gandorhun.
# Missing Results.
# ------------
# Retrieving Results for Index 547: Zapolyarnyy.
# Nearest Hotel Pechenga.
# ------------
# Retrieving Results for Index 548: Samarai.
# Nearest Hotel Nuli Sapi.
# ------------
# Retrieving Results for Index 549: Nerchinskiy Zavod.
# Nearest Hotel Tat'yana.
# ------------
# Retrieving Results for Index 550: Bose.
# Nearest Hotel Locanda Borgo Antico.
# ------------
# Retrieving Results for Index 551: Dakar.
# Nearest Hotel Redface Studios Meublés.
# ------------
# Retrieving Results for Index 552: Barão de Melgaço.
# Nearest Hotel Tuiuiu Pantanal Hotel.
# ------------
# Retrieving Results for Index 553: Mumford.
# Nearest Hotel Spanish Villa.
# ------------
# Retrieving Results for Index 554: Jalu.
# Nearest Hotel صاحبة الفخامة.
# ------------
# Retrieving Results for Index 555: Broken Hill.
# Nearest Hotel Royal Exchange Hotel.
# ------------
# Retrieving Results for Index 556: Noyabrsk.
# Nearest Hotel Hotel Uyutnaya.
# ------------
# Retrieving Results for Index 557: Pemangkat.
# Nearest Hotel Ramah Kost KITA.
# ------------
# Retrieving Results for Index 558: Kawalu.
# Nearest Hotel KOSAN UNGU UNSIK.
# ------------
# Retrieving Results for Index 559: Emerald.
# Nearest Hotel The Irish Village.
# ------------
# Retrieving Results for Index 560: Mayya.
# Missing Results.
# ------------
# Retrieving Results for Index 561: Abu Dhabi.
# Nearest Hotel Ramee Garden Hotel Apartments.
# ------------
# Retrieving Results for Index 562: Bubaque.
# Nearest Hotel Casa Dora, Bubaque.
# ------------
# Retrieving Results for Index 563: Poya.
# Missing Results.
# ------------
# Retrieving Results for Index 564: São João da Barra.
# Nearest Hotel Pousada Porto De Canoas.
# ------------
# Retrieving Results for Index 565: Camopi.
# Nearest Hotel La pousada.
# ------------
# Retrieving Results for Index 566: Elliot.
# Nearest Hotel Rose Garden Dinner Bed and Breakfast.
# ------------
# Retrieving Results for Index 567: Luganville.
# Nearest Hotel The Espiritu Hotel.
# ------------
# Retrieving Results for Index 568: Kupang.
# Nearest Hotel Hotel On The Rock by Prasanthi.
# ------------
# Retrieving Results for Index 569: Chandigarh.
# Nearest Hotel Hotel Oyster.
# ------------
# Retrieving Results for Index 570: ‘Ewa Beach.
# Nearest Hotel Uncle Junior Robert.
# ------------
# Retrieving Results for Index 571: Ulladulla.
# Nearest Hotel Sandpiper Motel.
# ------------
# Retrieving Results for Index 572: Semey.
# Nearest Hotel Grand Hotel Semey.
# ------------
# Retrieving Results for Index 573: Kilindoni.
# Nearest Hotel Bustani B&B.
# ------------
# Retrieving Results for Index 574: Bay City.
# Nearest Hotel DoubleTree by Hilton Hotel Bay City - Riverfront.
# ------------

# %%
hotel_df
# Out:
#                 City  Latitude  Longitude  Max Temperature  Humidity  \
# 0              Edson   53.5835  -116.4356            59.14        36
# 1          Guangzhou   23.1167   113.2500            60.94        71
# 2         Nikolskoye   59.7035    30.7861            53.87        85
# 3    Havre-St-Pierre   50.2334   -63.5986            50.00        87
# 4           Kuril'sk   45.2333   147.8833            41.11        84
# ..               ...       ...        ...              ...       ...
# 570       ‘Ewa Beach   21.3156  -158.0072            84.15        62
# 571        Ulladulla  -35.3500   150.4667            66.09        84
# 572            Semey   50.4111    80.2275            43.86        83
# 573        Kilindoni   -7.9139    39.6668            77.50        77
# 574         Bay City   43.5945   -83.8889            54.64        93
#
#      Cloudiness  Wind Speed Country        Date  \
# 0             1        8.05      CA  1634854598
# 1            95       12.75      CN  1634854289
# 2           100       16.40      RU  1634854598
# 3             1        4.61      CA  1634854598
# 4           100        4.29      RU  1634854599
# ..          ...         ...     ...         ...
# 570          75       10.00      US  1634854787
# 571          32        2.15      AU  1634854788
# 572         100       16.55      KZ  1634854789
# 573          19       12.08      TZ  1634854789
# 574          90       18.41      US  1634854707
#
#                                            Hotel Name
# 0    Holiday Inn Express & Suites Edson, an IHG Hotel
# 1                                     Guangzhou Hotel
# 2                             Tourist House - Sablino
# 3                                   Auberge Niapiskau
# 4                                        Hotel Ostrov
# ..                                                ...
# 570                               Uncle Junior Robert
# 571                                   Sandpiper Motel
# 572                                 Grand Hotel Semey
# 573                                       Bustani B&B
# 574  DoubleTree by Hilton Hotel Bay City - Riverfront
#
# [575 rows x 10 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Add marker layer ontop of heat map
hotel_details = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

locations = hotel_df[["Latitude", "Longitude"]]
markers = gmaps.marker_layer(locations)
# Display figure
humidity_fig.add_layer(markers)
humidity_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
